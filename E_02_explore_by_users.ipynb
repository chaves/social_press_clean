# %% [markdown]
# ## Explore data by users

# %%
import pandas as pd

# %%
INTPUT_FILE_GZIP = './_sources_final/pickles/pression_sociale_rounds_1_2_3_clean_str.pickle.gzip'

# %%
df = pd.read_pickle(INTPUT_FILE_GZIP, compression='gzip')

# %%
df_users_100 = df.usernameTweet.value_counts().loc[lambda x : x > 99].to_frame().reset_index()

# %%
len(df_users_100)
# Out:
# 9887

# %%
df_users_100.columns = ['userName', 'nbTweets']
df_users_100.head(2)
# Out:
#      userName  nbTweets
# 0  sainsburys    131678
# 1   McDonalds     80197

# %%
OUTPUT_FILE = './_sources_final/controls/02_users_100_counts.xls'

# %%
df_users_100.to_excel(OUTPUT_FILE)

# %%
df_users_100.head(100)
# Out:
#            userName  nbTweets
# 0        sainsburys    131678
# 1         McDonalds     80197
# 2   ASOS_HeretoHelp     79314
# 3             z3zro     52914
# 4     PokeMaster409     46342
# 5      NatWest_Help     32143
# 6          waitrose     24015
# 7       TandMProdCo     23583
# 8    housepassionuk     21267
# 9        Dominos_UK     19635
# 10            DJLNR     16085
# 11     Honda_BF_New     16024
# 12            Tesco     14228
# 13       UKdealshot     12704
# 14    aldi_fahreza_     11996
# 15    Honda_BF_Used     11843
# 16     Edgar_Braman     10966
# 17     admiral_baby     10597
# 18  Windsorhondacar     10104
# 19         asda_maq      9451
# 20   mobiledirectuk      9326
# 21          dominos      9068
# 22          Betfred      8961
# 23            Skype      8468
# 24  windsorhondanew      8063
# 25      UK_TopDeals      8001
# 26         eyalfeed      7720
# 27           sm11ff      7566
# 28    _MrDavidJones      7126
# 29  AmericanBanking      7097
# ...
